# %% [markdown]
# # Project: Candy Data Cleaning

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# ### Dataset Description
#
# > i will go through candy data 2017 , this data has :
# - Internal_ID
# - Q1-Going Out?: Are you actually going trick or treating yourself? "has values `Yes or No`"
# - Q2-Gender
# - Q3-Age: Numerical field
# - Q4-Country: Text Field, but users have written their own version of the names. Example, for America, there are entries such as USA, us, US, America so we should consider that while cleanning
# - Q5-State/Province: Text Field, but users have written their own version of the names. Same as the country data.
# - Q6-Joy Or Despair: All kinds of chocolate bars are the questions with three distinct options to choose from (Joy, Meh, Despair).
# - Q7-Joy Other: Text Field to write items not included above that give you JOY. Lots of missing values.
# - Q8-Despair Other: Text Field ti write items not included above that give you DESPAIR. Lots of missing values.
# - Q9-Other Comments: Text Field. Lots of missing values.
# - Q10-Dress: Binary field. Missing values present
# - Unnamed: 113
# - Q11-Day: Binary Answer Field. Missing values present

# %% [markdown]
# ### <font color = 'white'>First we import libraries and read the data:</font>

# %%
import pandas as pd,numpy as np,warnings,matplotlib.pyplot as plt, seaborn as sns
warnings.filterwarnings('ignore')
pd.set_option('display.max_column',None)

# %matplotlib inline

# %%
data = pd.read_excel('../Datasets/Candyhierarchy2017.xlsx')

# %%
data.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 0                           NaN              NaN                      NaN
# 1                           JOY              MEH                  DESPAIR
# 2                           NaN              NaN                      NaN
# 3                           JOY              MEH                      MEH
# 4                           JOY          DESPAIR                      MEH
#
#   Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 0                           NaN              NaN                NaN
# 1                       DESPAIR          DESPAIR            DESPAIR
# 2                           NaN              NaN                NaN
# 3                       DESPAIR              MEH            DESPAIR
# 4                       DESPAIR              MEH            DESPAIR
#
#   Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 0                    NaN               NaN                     NaN
# 1                DESPAIR           DESPAIR                     MEH
# 2                    NaN               NaN                     NaN
# 3                DESPAIR               MEH                     MEH
# 4                DESPAIR               MEH                     MEH
#
#   Q6 | Candy Corn  \
# 0             NaN
# 1             MEH
# 2             NaN
# 3         DESPAIR
# 4         DESPAIR
#
#   Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Q6 | Caramellos Q6 | Cash, or other forms of legal tender Q6 | Chardonnay  \
# 0             NaN                                       NaN             NaN
# 1             MEH                                       JOY             MEH
# 2             NaN                                       NaN             NaN
# 3             MEH                                       JOY             MEH
# 4             JOY                                       MEH             JOY
#
#   Q6 | Chick-o-Sticks (we don’t know what that is) Q6 | Chiclets  \
# 0                                              NaN           NaN
# 1                                          DESPAIR       DESPAIR
# 2                                              NaN           NaN
# 3                                              JOY           MEH
# 4                                          DESPAIR       DESPAIR
#
#   Q6 | Coffee Crisp Q6 | Creepy Religious comics/Chick Tracts  \
# 0               NaN                                       NaN
# 1           DESPAIR                                   DESPAIR
# 2               NaN                                       NaN
# 3           DESPAIR                                   DESPAIR
# 4               MEH                                   DESPAIR
#
#   Q6 | Dental paraphenalia Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 0                      NaN       NaN            NaN                NaN
# 1                  DESPAIR       MEH            JOY            DESPAIR
# 2                      NaN       NaN            NaN                NaN
# 3                  DESPAIR       JOY            JOY                MEH
# 4                  DESPAIR       MEH            JOY            DESPAIR
#
#   Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 0                              NaN              NaN                   NaN
# 1                          DESPAIR          DESPAIR               DESPAIR
# 2                              NaN              NaN                   NaN
# 3                              MEH              JOY                   JOY
# 4                          DESPAIR          DESPAIR                   MEH
#
#   Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 0                 NaN                          NaN
# 1                 MEH                      DESPAIR
# 2                 NaN                          NaN
# 3                 MEH                      DESPAIR
# 4                 MEH                      DESPAIR
#
#   Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 0                          NaN             NaN                NaN
# 1                          MEH             MEH            DESPAIR
# 2                          NaN             NaN                NaN
# 3                          JOY             MEH                MEH
# 4                          JOY             MEH            DESPAIR
#
#   Q6 | Heath Bar Q6 | Hershey's Dark Chocolate Q6 | Hershey’s Milk Chocolate  \
# 0            NaN                           NaN                           NaN
# 1            MEH                           JOY                           JOY
# 2            NaN                           NaN                           NaN
# 3        DESPAIR                           MEH                           MEH
# 4        DESPAIR                           JOY                           MEH
#
#   Q6 | Hershey's Kisses Q6 | Hugs (actual physical hugs)  \
# 0                   NaN                              NaN
# 1                   MEH                          DESPAIR
# 2                   NaN                              NaN
# 3                   MEH                              MEH
# 4                   MEH                          DESPAIR
#
#   Q6 | Jolly Rancher (bad flavor) Q6 | Jolly Ranchers (good flavor)  \
# 0                             NaN                               NaN
# 1                         DESPAIR                               MEH
# 2                             NaN                               NaN
# 3                             MEH                               MEH
# 4                             MEH                               JOY
#
#   Q6 | JoyJoy (Mit Iodine!) Q6 | Junior Mints Q6 | Senior Mints  \
# 0                       NaN               NaN               NaN
# 1                   DESPAIR           DESPAIR           DESPAIR
# 2                       NaN               NaN               NaN
# 3                   DESPAIR           DESPAIR           DESPAIR
# 4                       MEH               JOY           DESPAIR
#
#   Q6 | Kale smoothie Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy  \
# 0                NaN                     NaN          NaN             NaN
# 1            DESPAIR                 DESPAIR          JOY         DESPAIR
# 2                NaN                     NaN          NaN             NaN
# 3            DESPAIR                     MEH          MEH             JOY
# 4            DESPAIR                     JOY          JOY             JOY
#
#   Q6 | LemonHeads Q6 | Licorice (not black) Q6 | Licorice (yes black)  \
# 0             NaN                       NaN                       NaN
# 1             MEH                       MEH                       JOY
# 2             NaN                       NaN                       NaN
# 3             JOY                       MEH                       JOY
# 4             JOY                       MEH                   DESPAIR
#
#   Q6 | Lindt Truffle Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike  \
# 0                NaN            NaN       NaN           NaN               NaN
# 1                MEH        DESPAIR   DESPAIR       DESPAIR               MEH
# 2                NaN            NaN       NaN           NaN               NaN
# 3                JOY        DESPAIR       JOY           MEH               MEH
# 4                JOY            MEH       MEH       DESPAIR               MEH
#
#   Q6 | Milk Duds Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s  \
# 0            NaN            NaN               NaN               NaN
# 1            MEH            JOY               JOY               MEH
# 2            NaN            NaN               NaN               NaN
# 3        DESPAIR            JOY               MEH               JOY
# 4            MEH            JOY               JOY               JOY
#
#   Q6 | Blue M&M's Q6 | Red M&M's Q6 | Green Party M&M's  \
# 0             NaN            NaN                    NaN
# 1             JOY            JOY                    JOY
# 2             NaN            NaN                    NaN
# 3             MEH            MEH                    MEH
# 4             JOY            JOY                    JOY
#
#   Q6 | Independent M&M's Q6 | Abstained from M&M'ing. Q6 | Minibags of chips  \
# 0                    NaN                          NaN                    NaN
# 1                    JOY                      DESPAIR                DESPAIR
# 2                    NaN                          NaN                    NaN
# 3                    MEH                          MEH                DESPAIR
# 4                    JOY                          MEH                DESPAIR
#
#   Q6 | Mint Kisses Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers  \
# 0              NaN              NaN              NaN               NaN
# 1              MEH          DESPAIR          DESPAIR           DESPAIR
# 2              NaN              NaN              NaN               NaN
# 3          DESPAIR              MEH              MEH           DESPAIR
# 4              JOY              JOY              MEH           DESPAIR
#
#   Q6 | Nerds Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 0        NaN                NaN               NaN        NaN          NaN
# 1    DESPAIR                JOY           DESPAIR    DESPAIR      DESPAIR
# 2        NaN                NaN               NaN        NaN          NaN
# 3        MEH                MEH               MEH    DESPAIR      DESPAIR
# 4        JOY                JOY               JOY        MEH      DESPAIR
#
#   Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 0            NaN                                                NaN
# 1        DESPAIR                                            DESPAIR
# 2            NaN                                                NaN
# 3        DESPAIR                                            DESPAIR
# 4            JOY                                            DESPAIR
#
#   Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces Q6 | Reggie Jackson Bar  \
# 0                             NaN                 NaN                     NaN
# 1                             JOY                 JOY                 DESPAIR
# 2                             NaN                 NaN                     NaN
# 3                             JOY                 MEH                     MEH
# 4                             JOY                 JOY                     MEH
#
#   Q6 | Rolos Q6 | Sandwich-sized bags filled with BooBerry Crunch  \
# 0        NaN                                                NaN
# 1        JOY                                            DESPAIR
# 2        NaN                                                NaN
# 3        MEH                                            DESPAIR
# 4        JOY                                                NaN
#
#   Q6 | Skittles Q6 | Smarties (American) Q6 | Smarties (Commonwealth)  \
# 0           NaN                      NaN                          NaN
# 1       DESPAIR                  DESPAIR                      DESPAIR
# 2           NaN                      NaN                          NaN
# 3       DESPAIR                  DESPAIR                          MEH
# 4           JOY                      JOY                      DESPAIR
#
#   Q6 | Snickers Q6 | Sourpatch Kids (i.e. abominations of nature)  \
# 0           NaN                                               NaN
# 1           MEH                                           DESPAIR
# 2           NaN                                               NaN
# 3           JOY                                               MEH
# 4           NaN                                               MEH
#
#   Q6 | Spotted Dick Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 0               NaN            NaN              NaN               NaN
# 1           DESPAIR            MEH          DESPAIR               MEH
# 2               NaN            NaN              NaN               NaN
# 3           DESPAIR            MEH              MEH               JOY
# 4           DESPAIR            JOY              JOY               MEH
#
#   Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 0                                  NaN         NaN           NaN
# 1                              DESPAIR     DESPAIR       DESPAIR
# 2                                  NaN         NaN           NaN
# 3                                  MEH         JOY           MEH
# 4                              DESPAIR         MEH       DESPAIR
#
#   Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 0                                             NaN                   NaN
# 1                                         DESPAIR                   JOY
# 2                                             NaN                   NaN
# 3                                         DESPAIR               DESPAIR
# 4                                         DESPAIR                   JOY
#
#   Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 0                               NaN            NaN       NaN
# 1                               JOY        DESPAIR       JOY
# 2                               NaN            NaN       NaN
# 3                               JOY            MEH       JOY
# 4                               JOY        DESPAIR       JOY
#
#   Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                                MEH
#
#   Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 0          NaN                       NaN              NaN
# 1      DESPAIR                   DESPAIR          DESPAIR
# 2          NaN                       NaN              NaN
# 3          JOY                       JOY          DESPAIR
# 4          JOY                       JOY          DESPAIR
#
#   Q6 | Whole Wheat anything Q6 | York Peppermint Patties  \
# 0                       NaN                          NaN
# 1                   DESPAIR                      DESPAIR
# 2                       NaN                          NaN
# 3                   DESPAIR                      DESPAIR
# 4                   DESPAIR                          JOY
#
#                                        Q7: JOY OTHER Q8: DESPAIR OTHER  \
# 0                                                NaN               NaN
# 1                                             Mounds               NaN
# 2                                                NaN               NaN
# 3  Reese's crispy crunchy bars, 5th avenue bars, ...               NaN
# 4                                                NaN               NaN
#
#                                   Q9: OTHER COMMENTS      Q10: DRESS  \
# 0                                                NaN             NaN
# 1  Bottom line is Twix is really the only candy w...  White and gold
# 2                                                NaN             NaN
# 3                             Raisins can go to hell  White and gold
# 4                                                NaN  White and gold
#
#   Unnamed: 113 Q11: DAY  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# 0          NaN      NaN                      NaN                   NaN
# 1          NaN   Sunday                      NaN                   1.0
# 2          NaN      NaN                      NaN                   NaN
# 3          NaN   Sunday                      NaN                   1.0
# 4          NaN   Friday                      NaN                   1.0
#
#    Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 0                NaN                 NaN                      NaN
# 1                NaN                 NaN                 (84, 25)
# 2                NaN                 NaN                      NaN
# 3                NaN                 NaN                 (75, 23)
# 4                NaN                 NaN                 (70, 10)

# %%
data.isna().sum()
# Out:
# Internal ID                    0
# Q1: GOING OUT?               110
# Q2: GENDER                    41
# Q3: AGE                       84
# Q4: COUNTRY                   64
#                             ...
# Q12: MEDIA [Daily Dish]     2375
# Q12: MEDIA [Science]        1098
# Q12: MEDIA [ESPN]           2361
# Q12: MEDIA [Yahoo]          2393
# Click Coordinates (x, y)     855
# Length: 120, dtype: int64

# %% [markdown]
# ### <font color = 'white'>It has alot of missing values, we will treat each column in different way</font>

# %%
data['Q1: GOING OUT?'].unique()
# Out:
# array([nan, 'No', 'Yes'], dtype=object)

# %% [markdown]
# #### <font color = 'White'>Changing columns names to be easy to use.</font>

# %%
cols = list(data.columns)
def ff (cols):
    new = []
    for col in cols:
        col=col[col.find(':')+1:]
        col = col.strip()
        new.append(col)
    return new
data.columns=ff(cols)
data.columns
# Out:
# Index(['Internal ID', 'GOING OUT?', 'GENDER', 'AGE', 'COUNTRY',
#        'STATE, PROVINCE, COUNTY, ETC', 'Q6 | 100 Grand Bar',
#        'Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)',
#        'Q6 | Any full-sized candy bar', 'Q6 | Black Jacks',
#        ...
#        'DESPAIR OTHER', 'OTHER COMMENTS', 'DRESS', '113', 'DAY',
#        'MEDIA [Daily Dish]', 'MEDIA [Science]', 'MEDIA [ESPN]',
#        'MEDIA [Yahoo]', 'Click Coordinates (x, y)'],
#       dtype='object', length=120)

# %% [markdown]
#  - in the row level I notice that some responses has skipped all questions in the servey and submit it!, i will drop these records that will not benifit us.

# %%
print(data.shape)
data.dropna(axis=0,thresh=80,inplace=True)
# Out:
# (2460, 120)

# %%
data.isna().sum().sort_values(ascending=False)
# Out:
# 113                              1732
# MEDIA [Yahoo]                    1676
# MEDIA [Daily Dish]               1659
# MEDIA [ESPN]                     1643
# OTHER COMMENTS                   1367
#                                  ...
# Q6 | Kit Kat                        5
# Q6 | Peanut M&M’s                   3
# Q6 | Hershey's Dark Chocolate       1
# Q6 | Hershey’s Milk Chocolate       1
# Internal ID                         0
# Length: 120, dtype: int64

# %%
print(data['GOING OUT?'].value_counts())
print(f"Missing Values is : {data['GOING OUT?'].isna().sum()}")
# Out:
# No     1448
# Yes     233
# Name: GOING OUT?, dtype: int64
# Missing Values is : 60

# %%
df= data.replace(np.nan,'SKIPPED')

# %%
def pie(column_name):
    go = df[column_name].value_counts()
    goind = go.index
    plt.pie(go,labels=goind,wedgeprops={'edgecolor':'black'},
            shadow=True,
            startangle=40,
            autopct = '%1.1f%%')
    plt.style.use('seaborn')

pie('GOING OUT?')
plt.title('Q: Are you actually going trick or treating yourself?')
plt.show()

# %% [markdown]
# #### <font color ='white'>It seems like most answers going for **No**</font>

# %% [markdown]
# ---

# %%
df['GENDER'].value_counts()
# Out:
# Male                  1042
# Female                 607
# I'd rather not say      58
# Other                   26
# SKIPPED                  8
# Name: GENDER, dtype: int64

# %%
dd = df.query('GENDER != "Male" and GENDER != "Female"')
print("Unvalid Answers: "+str(len(dd)))
df.drop(dd.index,inplace=True)
# Out:
# Unvalid Answers: 92

# %%
pie('GENDER')
plt.title('Gender')
plt.show()

# %% [markdown]
# ---

# %%
df['AGE'].unique()
# Out:
# array([44, 40, 23, 'SKIPPED', 33, 53, 56, 64, 43, 37, 48, 49, 34, 35, 38,
#        58, 50, 47, 52, 63, 65, 45, 41, 31, 59, 61, 46, 54, 62, 29, 42, 36,
#        32, 28, 69, 67, 39, 30, 25, 22, 51, 70, 24, 27, 19, 'Old enough',
#        57, 66, 12, 'Many', 60, 55, '?', 11, 'no', 68, 20, 21, 6, 10, 71,
#        13, 26, '45-55', 72, 9, 74, 18, 'older than dirt', 15, 8, 75,
#        'Enough', 7, 'Over 50', 90, 76, 16, 'ancient', 'OLD', 14,
#        'MY NAME JEFF', 4, 73, 'old enough',
#        'I can remember when Java was a cool new language'], dtype=object)

# %%
unvalidlist=set()
validlist = []
for i in df['AGE']:
    try:
        jj = int(i)
        validlist.append(i)
    except:
        unvalidlist.add(i.lower())
print(unvalidlist)
di = {}
# for un in unvalidlist:
# Out:
# {'45-55', 'ancient', 'enough', '?', 'many', 'old', 'skipped', 'old enough', 'older than dirt', 'over 50', 'i can remember when java was a cool new language', 'no', 'my name jeff'}

# %%
fig,ax = plt.subplots()
plt.hist(validlist,bins=15)
med = np.median(validlist)
ax.axvline(med, color='red', label=f"Median = {med}", linewidth=1)
plt.legend()
plt.show()

# %%
for i in unvalidlist:
    if 'old' in i or 'many' in i :
        di[i] = 43+10
    else:
        di[i] = int(med)
di['45-55']=50
print(di)
# Out:
# {'45-55': 50, 'ancient': 43, 'enough': 43, '?': 43, 'many': 53, 'old': 53, 'skipped': 43, 'old enough': 53, 'older than dirt': 53, 'over 50': 43, 'i can remember when java was a cool new language': 43, 'no': 43, 'my name jeff': 43}

# %%
df['AGE'] = df['AGE'].astype(str).apply(lambda x : x.lower()).replace(di)
df['AGE'] = pd.to_numeric(df['AGE'])

# %%
pd.DataFrame(df['AGE'].describe()).T
# Out:
#       count       mean        std  min   25%   50%   75%   max
# AGE  1649.0  42.753184  11.399107  4.0  35.0  43.0  50.0  90.0

# %%
fig,ax = plt.subplots()
bi = [x for x in range(4,90,5)]
plt.hist(df['AGE'],bins=bi)
med = np.median(df['AGE'])
ax.axvline(med, color='red', label=f"Median = {med}", linewidth=1)
plt.legend()
plt.xticks([x for x in range(4,90+5,10)])
plt.title('Age Distribution for Candy Survey')
plt.ylabel('Number of Responses')
plt.xlabel('Age')
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# #### <font color = 'White'>Age has a normal distribution!</font>
# <br>

# %%
print(df['COUNTRY'].nunique())
df['COUNTRY'].unique()
# Out:
# 87
# array(['USA ', 'us', 'usa', 'SKIPPED', 'canada', 'Canada', 'Us', 'US',
#        'Murica', 'USA', 'United States', 'united states', 'Usa',
#        'United staes', 'United Kingdom', 'United States of America',
#        'UAE', 'United States ', 'canada ', 'United states', 'u.s.a.',
#        'france', 'United States of America ', 'america', 'U.S.A.',
#        'Mexico', 'Canada ', 'united states of america', 'US of A', 'UK',
#        'North Carolina ', 'uk', 'Netherlands', 'Europe', 'U S', 'u.s.',
#        'Costa Rica', 'The United States of America', 'Greece',
#        'The United States', 'USA? Hard to tell anymore..', "'merica",
#        'United State', 'France', 'U.S.', 'Can', 'Canae', 'Trumpistan',
#        'Ireland', 'United Sates', 'Korea', 'Australia', 'California',
#        'Unites States', 'Japan', 'USa',
#        'I pretend to be from Canada, but I am really from the United States.',
#        'Usa ', 'Canada`', 'Scotland', 'Denmark', 'France ', 'Switzerland',
#        'South Korea', 'New Jersey', 'CANADA', 'United Stated', 'Germany',
#        'America', 'United Statss', 'endland', 'murrika', 'united States ',
#        'germany', 'N. America', 'USSA', 'Taiwan', 'China', 'spain',
#        'U.S. ', 'Narnia', 'u s a', 'United Statea',
#        'subscribe to dm4uz3 on youtube', 'USA USA USA!!!!',
#        "I don't know anymore", 'Fear and Loathing'], dtype=object)

# %%
df['COUNTRY'] = df['COUNTRY'].apply(lambda x : x.lower().strip())

from fuzzywuzzy import fuzz

def matching_usa(col):
    sett = ['usa','united states','america','us of america','us','u.s.a','u s a','usausa','new york','new jersey','california']
    for i in sett:
        if fuzz.token_set_ratio(i,col)>70:
            return 'united states'
        
    sett = ['england','uk','united kingdom']
    for i in sett:
        if fuzz.token_set_ratio(i,col)>70:
            return 'united kingdom'
    sett = ['canada','can']
    for i in sett:
        if fuzz.token_set_ratio(i,col)>70:
            return 'canada'
    return col
        
df['COUNTRY'] = df['COUNTRY'].apply(matching_usa)
nn = []
for i in df['COUNTRY']:
    if len(i)>len('united states '):
        nn.append(i)
print(nn)
df['COUNTRY'].replace(nn,'SKIPPED',inplace=True)

unv = ['earth','trumpistan','ahem....amerca','murrika']
df['COUNTRY'] = df['COUNTRY'].apply(lambda x : 'SKIPPED' if x in unv else x)
df['COUNTRY'].value_counts()
# Out:
# ['subscribe to dm4uz3 on youtube', "i don't know anymore", 'fear and loathing']
# united states     1435
# canada             145
# united kingdom      19
# skipped              9
# germany              5
# SKIPPED              5
# netherlands          4
# japan                3
# france               3
# scotland             3
# switzerland          2
# denmark              2
# mexico               2
# korea                1
# australia            1
# north carolina       1
# greece               1
# costa rica           1
# europe               1
# south korea          1
# uae                  1
# taiwan               1
# china                1
# spain                1
# narnia               1
# Name: COUNTRY, dtype: int64

# %%
dd = df['COUNTRY'].value_counts(ascending = False)
# print(dd)
fig,ax=plt.subplots(figsize =(16, 9))
ax.barh(dd.index[:5],dd[:5])
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
    
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
ax.invert_yaxis()

for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.4,
             str(round((i.get_width()), 2))+"",
             fontsize = 10, fontweight ='bold',
             color ='grey')

plt.title("Most five Countries in the Data")
plt.show()

# %% [markdown]
# ### <font color ='white'>America is the most appeared country in the data then Canada</font>
# <br>

# %% [markdown]
# ---

# %%
df.rename(columns ={'STATE, PROVINCE, COUNTY, ETC':'STATE'},inplace=True)

# %%
print(df['STATE'].nunique())
df['STATE'].sort_values().unique()
# Out:
# 396
# array(['AB', 'AZ', 'Abu Dhabi', 'Alabama', 'Alaska',
#        'Alaska, Matanuska-Susitna Borough', 'Alberta', 'Alberta ',
#        'America', 'Arizona', 'Arizona ', 'Arkansas', 'Atlanta, GA', 'Az',
#        'BC', 'BERKELEY, CA', 'Baja California', 'Bc', 'Bloomington, IN',
#        'Bristol County, Rhode Island', 'British Columbia',
#        'British Columbia ', 'Brooklyn', 'Buncombe County, North Carolina',
#        'CA', 'CA, Alameda', 'CO', 'CO, Larimer County', 'COLORADO', 'CT',
#        'Ca', 'Califor', 'California', 'California ',
#        'California, Alameda',
#        'California, Contra Costa County, Pleasant Hill',
#        'California, Mendocino County', 'California, San Diego',
#        'California, San Francisco', 'California, USA',
#        'Carver county, MN', 'Chicago, IL', 'Chicago, Illinois', 'Co',
#        'Colorado', 'Colorado ', 'Colorado larimer county',
#        'Colorado, Jefferson county ', 'Connecticut', 'Connecticut ',
#        'Cook', 'Cuyahoga County, Ohio', 'DC', 'DC ', 'Dc', 'Derbyshire',
#        'Devonshire', 'District of Columbia',
#        'Dona Ana county, New Mexico', 'Dublin',
#        'Durham County, North Carolina', 'Edinburgh', 'FL', 'FL ', 'Fl',
#        'Florida', 'Florida ', 'GA', 'Georgia', 'Georgia ', 'Glasgow',
#        'Glendora, Los Angeles, California', 'Greater London',
#        'Greifswald', 'HI', 'Hawaii', 'Henrico, VA', 'Hessen', 'Hong Kong',
#        'IA', 'IL', 'IN', 'Ia', 'Idaho', 'Idaho ', 'Idaho ada', 'Idf',
#        'Il', 'Illinois', 'Illinois ', 'Illinois  ', 'Indiana', 'Iowa',
#        'KS', 'KY', 'Kalamazoo County, MI', 'Kansas', 'Kansas ',
#        'Kentucky', 'Kentucky ', 'Kildare', 'Kings, New York ',
#        'Knox county, Tennessee', 'Ks', 'Ky', 'La', 'London',
#        'Los Angeles, California', 'Louisiana', 'MA', 'MARYLAND', 'MD',
#        'MD ', 'MI', 'MN', 'MO', 'MS', 'Ma', 'Maine', 'Manchester',
#        'Manitoba', 'Manitoba ', 'Mannheim, Baden-Württemberg ', 'Marne',
#        'Maryland', 'Massachusetts', 'Massachusetts ',
#        'Massachusetts, Plymouth county', 'Massachussets ', 'Md', 'Merlin',
#        'Mexico City', 'Mi', 'Michigan', 'Michigan ',
#        'Michigan, Shiawassee County', 'Midlothian', 'Minnesota',
#        'Minnesota ', 'Missouri', 'Missouri ', 'Mn', 'Mo', 'Monroe county',
#        'Montana', 'Mt', 'Munster', 'NC', 'ND', 'NE', 'NH', 'NJ',
#        'NJ, Gloucester', 'NJ; Essex', 'NL', 'NM', 'NOYB', 'NS', 'NV',
#        'NY', 'NY, Tompkins County', 'Nc', 'Nebraska', 'Nebraska ',
#        'Nevada', 'New Hampshire', 'New Hampshire ', 'New Jersey',
#        'New Jersey ', 'New Mexico', 'New Orleans la ', 'New York',
#        'New York ', 'New York County, New York City, New York State',
#        'New jersey', 'New york', 'Newfoundland',
#        'Newfoundland and Labrador', 'Nh', 'Nj', 'Nj ', 'Nm',
#        'Noord-Holland', 'North Carolina', 'North Dakota', 'North dakota',
#        'Northampton County, PA', 'Northbrook, IL', 'Nova Scotia', 'Ny',
#        'Ny ', 'OH', 'OK', 'ON', 'ONTARIO', 'OR', 'OREGON',
#        'Oakland County, Michigan', 'Oakland, California', 'Ohio', 'Ohio ',
#        'Oklahoma', 'Oklahoma ', 'On', 'Ontario', 'Ontario ',
#        'Ontario,  Canada', 'Or', 'Oregon', 'Oregon ',
#        'Oregon - but will be in Washington for Halloween',
#        'Oregon, Multnomah County', 'Osaka', 'Oxfordshire', 'PA',
#        'PENNSYLVANIA', 'PEnnsylvania', 'Pa', 'Pennsylvania',
#        'Pennsylvania ', 'Philadelphia', 'Philadelphia PA',
#        'Philadelphia, PA', 'Portland, maine', 'Psychotic', 'Quebec',
#        'Quenec', 'RI', 'Rappahannock County, VA', 'Rhode Island', 'Ri',
#        'Rotterdam', 'SC', 'SC ', 'SKIPPED', 'San Jose',
#        'Santa Barbara co. California', 'Santa Clara County, California',
#        'Santa Cruz County, California', 'Saskatchewan', 'Scotland',
#        'Seoul', 'South Carolina', 'South Carolina ', 'South Dakota',
#        'South Holland', 'Strathclyde', 'Surrey', 'TEXAS', 'TN', 'TX',
#        'Tehama', 'Tennessee', 'Tennessee ', 'Tennessee, Knox County',
#        'Texas', 'Texas ',
#        "The Democratic People's Republic of North Carolina", 'The Shore',
#        'Tn', 'Tokyo', 'Toronto, Ontario', 'Tree Town, USA', 'Tx', 'USA ',
#        'UT', 'UT, Salt Lake', 'Utah', 'VA', 'VT', 'Va', 'Vancouver, Wa',
#        'Vaud', 'Vermont', 'Vermont ', 'Victoria', 'Virginia', 'Virginia ',
#        'Virginia, Arlington', 'WA', 'WASHINGTON DC', 'WI', 'WV',
#        'WV, Kanawha County ', 'Wa', 'Washingto', 'Washington',
#        'Washington ', 'Washington DC', 'Washington State',
#        'Washington State, King County, City of Seattle',
#        'Washington state ', 'Washington state, Kitsap County',
#        'Washington, Clark ', 'Washington, DC', 'Washington, King',
#        'Washington, King County', 'Washington, seattle, king',
#        'West Virginia', 'West Yorkshire', 'Whatcom County, WA', 'Wi',
#        'Wisconsin', 'Wisconsin ', 'Wyoming', 'Wyoming ',
#        'alameda county, california', 'alberta', 'ar', 'arlington, va',
#        'az', 'bc', 'british columbia', 'ca', 'cailifornia', 'calif',
#        'california', 'california ', 'colorado', 'connecticut', 'ct', 'dc',
#        'delaware', 'exton pa', 'florida', 'hi', 'il', 'ill', 'illinois',
#        'in', 'indiana', 'indiana ', 'iowa', 'kansas', 'kent', 'kentucky',
#        'louisiana', 'ma', 'madrid', 'maine', 'maryland', 'massachusetts',
#        'md', 'mi', 'minnesota', 'mississippi', 'mn', 'mo', 'montana',
#        'nc', 'new hampshire', 'new york', 'new york ', 'newfoundland',
#        'nh', 'nj', 'north carolina', 'nova scotia', 'ny', 'nyc', 'ohio',
#        'oklahoma', 'ont', 'ontario', 'or', 'orange county, ca', 'oregon',
#        'pa', 'pennsylvania', 'pennsylvania, northampton couny, easton',
#        'philadelphia', 'phoenix, maricopa county, arizona',
#        'rhode island', 'ri', 'sc', 'suffolk county ny', 'tennessee',
#        'texas', 'tn', 'tx', 'ulster county, NY', 'ur mom', 'utah', 'va',
#        'virginia', 'vt', 'wa', 'wa, spokane', 'washington',
#        'west virginia', 'wisconsin', 'wv', 'wyoming', 'yukon', '|NC',
#        'Ørbæk'], dtype=object)

# %%
df['STATE'] = df['STATE'].apply(lambda x : x.lower().strip())
list_rep = ['city','state','county','ur mom','dona ana , ','usa','the shore','the democratic people\'s republic of','greater ','hi',
'skipped',' - but will be in wasngton for halloween','|']
for i in list_rep:
    df['STATE']=df['STATE'].str.replace(i,'')
df['STATE'] = df['STATE'].str.replace('new york , new york , new york','')
df['STATE']=df['STATE'].replace({'':'skipped','ca':'california','ny':'new york',
                                 'wa':'wasngton','ma':'massachusetts','fl':'florida','il':'illinois',
                                 'ill':'illinois','nj':'new jersey','co':'colorado','ga':'georgia',
                                 'nc':'north carolina','in':'indiana','tn':'tennessee','va':'virginia',
                                'tx':'texas'})

# %% [markdown]
# - The reference for states abbreviations<font color ='gray'> https://en.wikipedia.org/wiki/List_of_U.S._state_and_territory_abbreviations</font>

# %%
df[df['COUNTRY']=='united states']['STATE'].value_counts()[:60]
# Out:
# california        207
# wasngton           76
# new york           73
# illinois           69
# texas              67
# massachusetts      59
# oregon             47
# virginia           46
# florida            34
# oo                 34
# pennsylvania       34
# colorado           33
# north carolina     31
# georgia            29
# pa                 25
# mn                 24
# new jersey         22
# micgan             21
# wisconsin          21
# indiana            21
# minnesota          19
# or                 17
# maine              16
# missouri           15
# maryland           14
# arizona            13
# skipped            13
# tennessee          13
# iowa               12
# mi                 12
# mo                 12
# utah               11
# kansas             10
# md                  9
# dc                  9
# oh                  8
# az                  8
# connecticut         8
# oklahoma            8
# nm                  7
# nh                  7
# louisiana           7
# kentucky            6
# ri                  6
# nevada              6
# montana             5
# hawaii              5
# alabama             5
# south carolina      5
# idaho               5
# ks                  5
# nebraska            5
# wv                  4
# sc                  4
# vt                  4
# nv                  4
# wi                  4
# ct                  4
# new mexico          4
# wasngton            4
# Name: STATE, dtype: int64

# %%
dd = df['STATE'].value_counts(ascending = False)
def barhh(data):
    dd = data
    fig,ax=plt.subplots(figsize =(16, 9))
    ax.barh(dd.index[:6],dd[:6])
    for s in ['top', 'bottom', 'left', 'right']:
        ax.spines[s].set_visible(False)

    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_tick_params(pad = 5)
    ax.yaxis.set_tick_params(pad = 10)
    ax.grid(b = True, color ='grey',
            linestyle ='-.', linewidth = 0.5,
            alpha = 0.2)
    ax.invert_yaxis()

    for i in ax.patches:
        plt.text(i.get_width()+0.2, i.get_y()+0.4,
                 str(round((i.get_width()), 2))+"",
                 fontsize = 10, fontweight ='bold',
                 color ='grey')
plt.style.use('fivethirtyeight')
barhh(dd)
plt.title("Most 6 States in united states")
plt.show()

# %% [markdown]
# #### <font color='white'> California is the most appeared state in USA</font>
# <br>

# %%
df.iloc[:,6:-11].head()
# Out:
#   Q6 | 100 Grand Bar  \
# 1                MEH
# 3                MEH
# 4                JOY
# 5                JOY
# 7                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                            DESPAIR
# 3                                            DESPAIR
# 4                                            DESPAIR
# 5                                            DESPAIR
# 7                                            DESPAIR
#
#   Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 1                           JOY              MEH                  DESPAIR
# 3                           JOY              MEH                      MEH
# 4                           JOY          DESPAIR                      MEH
# 5                           JOY          SKIPPED                  SKIPPED
# 7                           JOY          DESPAIR                  DESPAIR
#
#   Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 1                       DESPAIR          DESPAIR            DESPAIR
# 3                       DESPAIR              MEH            DESPAIR
# 4                       DESPAIR              MEH            DESPAIR
# 5                       SKIPPED              MEH                MEH
# 7                           MEH              JOY                MEH
#
#   Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 1                DESPAIR           DESPAIR                     MEH
# 3                DESPAIR               MEH                     MEH
# 4                DESPAIR               MEH                     MEH
# 5                DESPAIR               JOY                 DESPAIR
# 7                    JOY               JOY                     JOY
#
#   Q6 | Candy Corn  \
# 1             MEH
# 3         DESPAIR
# 4         DESPAIR
# 5             MEH
# 7             JOY
#
#   Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                            DESPAIR
# 3                                            DESPAIR
# 4                                            DESPAIR
# 5                                                MEH
# 7                                            DESPAIR
#
#   Q6 | Caramellos Q6 | Cash, or other forms of legal tender Q6 | Chardonnay  \
# 1             MEH                                       JOY             MEH
# 3             MEH                                       JOY             MEH
# 4             JOY                                       MEH             JOY
# 5             JOY                                       JOY             JOY
# 7             JOY                                       JOY             JOY
#
#   Q6 | Chick-o-Sticks (we don’t know what that is) Q6 | Chiclets  \
# 1                                          DESPAIR       DESPAIR
# 3                                              JOY           MEH
# 4                                          DESPAIR       DESPAIR
# 5                                              MEH           MEH
# 7                                          DESPAIR           MEH
#
#   Q6 | Coffee Crisp Q6 | Creepy Religious comics/Chick Tracts  \
# 1           DESPAIR                                   DESPAIR
# 3           DESPAIR                                   DESPAIR
# 4               MEH                                   DESPAIR
# 5               JOY                                   DESPAIR
# 7               MEH                                   DESPAIR
#
#   Q6 | Dental paraphenalia Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 1                  DESPAIR       MEH            JOY            DESPAIR
# 3                  DESPAIR       JOY            JOY                MEH
# 4                  DESPAIR       MEH            JOY            DESPAIR
# 5                      MEH       MEH            JOY            SKIPPED
# 7                  DESPAIR       MEH            MEH                JOY
#
#   Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 1                          DESPAIR          DESPAIR               DESPAIR
# 3                              MEH              JOY                   JOY
# 4                          DESPAIR          DESPAIR                   MEH
# 5                          DESPAIR              MEH                   JOY
# 7                          DESPAIR          DESPAIR               DESPAIR
#
#   Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 1                 MEH                      DESPAIR
# 3                 MEH                      DESPAIR
# 4                 MEH                      DESPAIR
# 5                 MEH                      DESPAIR
# 7             DESPAIR                      DESPAIR
#
#   Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 1                          MEH             MEH            DESPAIR
# 3                          JOY             MEH                MEH
# 4                          JOY             MEH            DESPAIR
# 5                          MEH             MEH                MEH
# 7                          JOY         DESPAIR            DESPAIR
#
#   Q6 | Heath Bar Q6 | Hershey's Dark Chocolate Q6 | Hershey’s Milk Chocolate  \
# 1            MEH                           JOY                           JOY
# 3        DESPAIR                           MEH                           MEH
# 4        DESPAIR                           JOY                           MEH
# 5            JOY                           JOY                           MEH
# 7        DESPAIR                           JOY                           MEH
#
#   Q6 | Hershey's Kisses Q6 | Hugs (actual physical hugs)  \
# 1                   MEH                          DESPAIR
# 3                   MEH                              MEH
# 4                   MEH                          DESPAIR
# 5                   MEH                              MEH
# 7                   MEH                          DESPAIR
#
#   Q6 | Jolly Rancher (bad flavor) Q6 | Jolly Ranchers (good flavor)  \
# 1                         DESPAIR                               MEH
# 3                             MEH                               MEH
# 4                             MEH                               JOY
# 5                             MEH                               MEH
# 7                         DESPAIR                           DESPAIR
#
#   Q6 | JoyJoy (Mit Iodine!) Q6 | Junior Mints Q6 | Senior Mints  \
# 1                   DESPAIR           DESPAIR           DESPAIR
# 3                   DESPAIR           DESPAIR           DESPAIR
# 4                       MEH               JOY           DESPAIR
# 5                   SKIPPED               JOY           SKIPPED
# 7                   DESPAIR           DESPAIR           DESPAIR
#
#   Q6 | Kale smoothie Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy  \
# 1            DESPAIR                 DESPAIR          JOY         DESPAIR
# 3            DESPAIR                     MEH          MEH             JOY
# 4            DESPAIR                     JOY          JOY             JOY
# 5            DESPAIR                 SKIPPED          JOY             MEH
# 7            DESPAIR                 DESPAIR          MEH             MEH
#
#   Q6 | LemonHeads Q6 | Licorice (not black) Q6 | Licorice (yes black)  \
# 1             MEH                       MEH                       JOY
# 3             JOY                       MEH                       JOY
# 4             JOY                       MEH                   DESPAIR
# 5             MEH                       MEH                       MEH
# 7             JOY                       MEH                   DESPAIR
#
#   Q6 | Lindt Truffle Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike  \
# 1                MEH        DESPAIR   DESPAIR       DESPAIR               MEH
# 3                JOY        DESPAIR       JOY           MEH               MEH
# 4                JOY            MEH       MEH       DESPAIR               MEH
# 5                JOY            MEH       JOY       SKIPPED               JOY
# 7            DESPAIR            MEH       JOY           JOY               JOY
#
#   Q6 | Milk Duds Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s  \
# 1            MEH            JOY               JOY               MEH
# 3        DESPAIR            JOY               MEH               JOY
# 4            MEH            JOY               JOY               JOY
# 5            JOY            JOY               JOY               JOY
# 7            JOY            JOY               JOY               JOY
#
#   Q6 | Blue M&M's Q6 | Red M&M's Q6 | Green Party M&M's  \
# 1             JOY            JOY                    JOY
# 3             MEH            MEH                    MEH
# 4             JOY            JOY                    JOY
# 5             JOY            JOY                SKIPPED
# 7             JOY            JOY                    JOY
#
#   Q6 | Independent M&M's Q6 | Abstained from M&M'ing. Q6 | Minibags of chips  \
# 1                    JOY                      DESPAIR                DESPAIR
# 3                    MEH                          MEH                DESPAIR
# 4                    JOY                          MEH                DESPAIR
# 5                SKIPPED                      SKIPPED                    JOY
# 7                    MEH                      DESPAIR                    JOY
#
#   Q6 | Mint Kisses Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers  \
# 1              MEH          DESPAIR          DESPAIR           DESPAIR
# 3          DESPAIR              MEH              MEH           DESPAIR
# 4              JOY              JOY              MEH           DESPAIR
# 5              JOY              JOY              JOY               MEH
# 7          DESPAIR          DESPAIR              MEH               MEH
#
#   Q6 | Nerds Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 1    DESPAIR                JOY           DESPAIR    DESPAIR      DESPAIR
# 3        MEH                MEH               MEH    DESPAIR      DESPAIR
# 4        JOY                JOY               JOY        MEH      DESPAIR
# 5        JOY                MEH               MEH    DESPAIR      DESPAIR
# 7        JOY                JOY               MEH    DESPAIR      DESPAIR
#
#   Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 1        DESPAIR                                            DESPAIR
# 3        DESPAIR                                            DESPAIR
# 4            JOY                                            DESPAIR
# 5            MEH                                            DESPAIR
# 7        DESPAIR                                            DESPAIR
#
#   Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces Q6 | Reggie Jackson Bar  \
# 1                             JOY                 JOY                 DESPAIR
# 3                             JOY                 MEH                     MEH
# 4                             JOY                 JOY                     MEH
# 5                             JOY                 JOY                 DESPAIR
# 7                             JOY                 JOY                 SKIPPED
#
#   Q6 | Rolos Q6 | Sandwich-sized bags filled with BooBerry Crunch  \
# 1        JOY                                            DESPAIR
# 3        MEH                                            DESPAIR
# 4        JOY                                            SKIPPED
# 5        JOY                                            DESPAIR
# 7        JOY                                            DESPAIR
#
#   Q6 | Skittles Q6 | Smarties (American) Q6 | Smarties (Commonwealth)  \
# 1       DESPAIR                  DESPAIR                      DESPAIR
# 3       DESPAIR                  DESPAIR                          MEH
# 4           JOY                      JOY                      DESPAIR
# 5           JOY                      JOY                          JOY
# 7           JOY                      MEH                          JOY
#
#   Q6 | Snickers Q6 | Sourpatch Kids (i.e. abominations of nature)  \
# 1           MEH                                           DESPAIR
# 3           JOY                                               MEH
# 4       SKIPPED                                               MEH
# 5           JOY                                           DESPAIR
# 7           MEH                                               JOY
#
#   Q6 | Spotted Dick Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 1           DESPAIR            MEH          DESPAIR               MEH
# 3           DESPAIR            MEH              MEH               JOY
# 4           DESPAIR            JOY              JOY               MEH
# 5           DESPAIR            MEH              MEH               MEH
# 7           DESPAIR            MEH              JOY               JOY
#
#   Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 1                              DESPAIR     DESPAIR       DESPAIR
# 3                                  MEH         JOY           MEH
# 4                              DESPAIR         MEH       DESPAIR
# 5                              SKIPPED     SKIPPED           MEH
# 7                                  MEH         MEH       DESPAIR
#
#   Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 1                                         DESPAIR                   JOY
# 3                                         DESPAIR               DESPAIR
# 4                                         DESPAIR                   JOY
# 5                                         DESPAIR                   JOY
# 7                                         DESPAIR                   JOY
#
#   Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 1                               JOY        DESPAIR       JOY
# 3                               JOY            MEH       JOY
# 4                               JOY        DESPAIR       JOY
# 5                               JOY            MEH       JOY
# 7                               MEH        DESPAIR       JOY
#
#   Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                            DESPAIR
# 3                                            DESPAIR
# 4                                                MEH
# 5                                            DESPAIR
# 7                                                JOY
#
#   Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 1      DESPAIR                   DESPAIR          DESPAIR
# 3          JOY                       JOY          DESPAIR
# 4          JOY                       JOY          DESPAIR
# 5      DESPAIR                       JOY          DESPAIR
# 7          MEH                   DESPAIR          DESPAIR
#
#   Q6 | Whole Wheat anything Q6 | York Peppermint Patties
# 1                   DESPAIR                      DESPAIR
# 3                   DESPAIR                      DESPAIR
# 4                   DESPAIR                          JOY
# 5                   DESPAIR                          JOY
# 7                   DESPAIR                      DESPAIR

# %%
the = df.iloc[:,6:-11]
candy,joy,Dis = [],[],[]
for i in the:
    candy.append(i[5:])
    joy.append(df[i].value_counts()['JOY'])
    Dis.append(df[i].value_counts()['DESPAIR'])

# %%
dd.head()
# Out:
#                                                    col  joy   DES
# 8                                    Broken glow stick   23  1506
# 74   Real Housewives of Orange County Season 9 Blue...   84  1381
# 28                             Gum from baseball cards   42  1364
# 100                                        White Bread   43  1356
# 42                                       Kale smoothie   92  1351

# %%
dd = pd.DataFrame()
dd['col'] = candy
dd['joy']=joy
dd['DES'] =Dis

fig,axes=plt.subplots(2,1,figsize=(6,12))

dd.sort_values(by='joy',ascending=False,inplace=True)
a= sns.barplot(ax = axes[0],y='col',x='joy',data=dd[:10],palette='Reds_r')
dd.sort_values(by='DES',ascending=False,inplace=True)
b = sns.barplot(ax = axes[1],y='col',x='DES',data=dd[:10],palette='crest_r')

axes[0].set_title('Most 10 Candies got "JOY"',size=10)
axes[0].set_xlabel("")
axes[0].set_ylabel("")

axes[1].set_title('Most 10 Candies got "DESPAIR"',size=10)
axes[1].set_xlabel("")
axes[1].set_ylabel("")



for i,j in zip(a.containers,b.containers):
    a.bar_label(i,)
    b.bar_label(j,)

 
fig.suptitle("People and Candies",size=25,ha='center')
plt.show()

# %%
df['DRESS'].value_counts()
# Out:
# White and gold    1000
# Blue and black     581
# SKIPPED             68
# Name: DRESS, dtype: int64

# %%
pie('DRESS')
plt.title("Dress Color",size=20,c='#eb9834')
plt.show()

# %% [markdown]
# ### <font color ='white'> Most People when they first seen that dress, was gold.</font>

# %%
pie('DAY')
plt.title("Day Prefered!")
plt.show()

# %%
df.drop(columns=['113'],inplace=True)

# %%
dadd = df.query('DAY == "Sunday"')
dd = dadd['STATE'].value_counts(ascending = False)
# print(dd)
fig,ax=plt.subplots(figsize =(16, 9))
ax.barh(dd.index[:6],dd[:6])
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
    
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
ax.invert_yaxis()

for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.4,
             str(round((i.get_width()), 2))+"",
             fontsize = 10, fontweight ='bold',
             color ='grey')

plt.title("People Who choosed Sunday")
plt.show()

# %%
df.iloc[:,-5:-1] = df.iloc[:,-5:-1].apply(lambda x: x.apply(lambda y: 0 if y == 'SKIPPED' else y))

# %%
df['MEDIA [Science]'].value_counts()
# Out:
# 1.0    1250
# 0.0     399
# Name: MEDIA [Science], dtype: int64

# %%
a=[60,80,96,1250]
labell = ['Yahoo','Daily Dish','ESPN','Science']
a
# Out:
# [60, 80, 96, 1250]

# %%
ax = sns.barplot(x=labell,y=a,palette='Set3')
plt.title('Media pressed')
plt.show()

# %% [markdown]
# #### <font color='white'>Most people here like to ckick out science content</font>

# %%
click = df['Click Coordinates (x, y)'].str.replace('[(),]','').str.strip()
x,y=[],[]
for i in click:
    try:
        x.append(int(i[0:2]))
        y.append(int(i[3:5]))
    except:
        continue
        
plt.scatter(x=x,y=y,alpha=0.8)
plt.title('Most Coordinates Clicked')
plt.show()
